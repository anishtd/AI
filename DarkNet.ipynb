# %% [markdown]
# <a href="https://colab.research.google.com/github/anishtd/AI/blob/master/DarkNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !ls '/content/drive/MyDrive/Yolo'
# Out:
# backup	  chart.png		   custom_weights  data
# bad.list  chart_yolov3_custom.png  darknet	   data.zip

# %%
# !unzip '/content/drive/MyDrive/Yolo/data.zip' -d '/content/drive/MyDrive/Yolo/'
# Out:
# Archive:  /content/drive/MyDrive/Yolo/data.zip
#   inflating: /content/drive/MyDrive/Yolo/data/asif (1).jpg
#   inflating: /content/drive/MyDrive/Yolo/data/asif (1).txt
#   inflating: /content/drive/MyDrive/Yolo/data/asif (10).jpg
#   inflating: /content/drive/MyDrive/Yolo/data/asif (10).txt
#   inflating: /content/drive/MyDrive/Yolo/data/asif (2).jpg
#   inflating: /content/drive/MyDrive/Yolo/data/asif (2).txt
#   inflating: /content/drive/MyDrive/Yolo/data/asif (3).jpg
#   inflating: /content/drive/MyDrive/Yolo/data/asif (3).txt
#   inflating: /content/drive/MyDrive/Yolo/data/asif (4).jpg
#   inflating: /content/drive/MyDrive/Yolo/data/asif (4).txt
#   inflating: /content/drive/MyDrive/Yolo/data/asif (5).jpg
#   inflating: /content/drive/MyDrive/Yolo/data/asif (5).txt
#   inflating: /content/drive/MyDrive/Yolo/data/asif (6).jpg
#   inflating: /content/drive/MyDrive/Yolo/data/asif (6).txt
#   inflating: /content/drive/MyDrive/Yolo/data/asif (7).jpg
# ...

# %%
! git clone 'https://github.com/AlexeyAB/darknet.git' 'darknet'
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15050, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 15050 (delta 16), reused 34 (delta 14), pack-reused 15002
# Receiving objects: 100% (15050/15050), 13.48 MiB | 19.14 MiB/s, done.
# Resolving deltas: 100% (10215/10215), done.

# %%
cd /content/drive/MyDrive/Yolo
# Out:
# /content/drive/MyDrive/Yolo

# %%
cd darknet
# Out:
# /content/drive/MyDrive/Yolo/darknet

# %%
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	json_mjpeg_streams.sh  scripts
# backup		darknet_images.py	LICENSE		       src
# build		darknet.py		Makefile	       vcpkg.json
# build.ps1	darknet_video.py	net_cam_v3.sh	       video_yolov3.sh
# cfg		data			net_cam_v4.sh	       video_yolov4.sh
# cmake		image_yolov3.sh		obj
# CMakeLists.txt	image_yolov4.sh		README.md
# darknet		include			results

# %%
# !make
# Out:
# chmod +x *.sh

# %%
cd ..
# Out:
# /content/drive/MyDrive/Yolo

# %%
# !chmod +x *.sh
# Out:
# chmod: cannot access '*.sh': No such file or directory

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74 -O custom_weights/darknet53.conv.74
# Out:
# --2021-05-22 06:52:30--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘custom_weights/darknet53.conv.74’
#
# custom_weights/dark 100%[===================>] 154.96M  55.3MB/s    in 2.8s
#
# 2021-05-22 06:52:33 (55.3 MB/s) - ‘custom_weights/darknet53.conv.74’ saved [162482580/162482580]

# %%
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	json_mjpeg_streams.sh  scripts
# backup		darknet_images.py	LICENSE		       src
# build		darknet.py		Makefile	       vcpkg.json
# build.ps1	darknet_video.py	net_cam_v3.sh	       video_yolov3.sh
# cfg		data			net_cam_v4.sh	       video_yolov4.sh
# cmake		image_yolov3.sh		obj
# CMakeLists.txt	image_yolov4.sh		README.md
# darknet		include			results

# %%
# !cd ..

# %%
cd ..
# Out:
# /content/drive/My Drive/Yolo

# %%
ls
# Out:
# backup/   chart.png                custom_weights/  data/
# bad.list  chart_yolov3_custom.png  darknet/         data.zip

# %%
# !chmod +x darknet/darknet

# %%
# !darknet/darknet detector train data/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weights/darknet53.conv.74 -dont_show
# Out:
#  GPU isn't used
#  OpenCV isn't used - data augmentation will be slow
# yolov3_custom
# mini_batch = 1, batch = 4, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
# ...

# %% [markdown]
# # New Section

# %%
# !darknet/darknet
# Out:
# usage: darknet/darknet <function>

# %% [markdown]
# # New Section
